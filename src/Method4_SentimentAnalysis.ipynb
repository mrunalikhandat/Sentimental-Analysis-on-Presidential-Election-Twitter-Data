# %%
import pandas as pd
import json
import textwrap
import string

tweets = []
for line in open('tweets.json', 'r'):
    tweets.append(json.loads(line))

obama_cnt = 0
romney_cnt = 0
obama_romney_cnt = 0

tweets_df = pd.DataFrame(columns=['id','tweet'],index=None)

# for tweet in tweets[0:10000]:
#     data = pd.DataFrame({"id":[tweet['id_str']],"tweet":[tweet['text']]})
#     tweets_df = tweets_df.append(data, ignore_index = True)

for i in range(0,len(tweets)):
    if(i % 100000 == 0):
        print("i:",i)
    obama = False;
    romney = False;
    for word in tweets[i]['text'].split():
#         print(word)
        if word.lower() in ["obama","barack","barackobama","obamabarack"]:
            obama = True
        if word.lower() in["mitt","romney","mittromney","romneymitt"]:
            romney = True
    if obama == True and romney == False:
        data = pd.DataFrame({"id":[tweets[i]['id_str']],"tweet":[tweets[i]['text']]})
        tweets_df = tweets_df.append(data, ignore_index = True)
        obama_cnt += 1
    elif obama == False and romney == True:
        data = pd.DataFrame({"id":[tweets[i]['id_str']],"tweet":[tweets[i]['text']]})
        tweets_df = tweets_df.append(data, ignore_index = True)
        romney_cnt += 1
#     elif obama == True and romney == True:
#         obama_romney_cnt += 1

print('Tweets about Obama: ' + str(obama_cnt))
print('Tweets about Romney: ' + str(romney_cnt))
# print(obama_romney_cnt)
# Out:
# i: 0
# i: 100000
# i: 200000
# i: 300000
# i: 400000
# i: 500000
# i: 600000
# i: 700000
# i: 800000
# i: 900000
# Tweets about Obama: 324805
# Tweets about Romney: 30092

# %%
tweets_df
# Out:
#                         id                                              tweet
# 0       246058206651117568  Can we please stop pretending that Obama is a ...
# 1       246058207460614144  RT @MotherJones: The official GOP response to ...
# 2       246058208463044608  RT @PolarCoug: Obama would never make a good r...
# 3       246058208584671234  RT @Zack_gale: You cant bag on Obama if you on...
# 4       246058212116267008  @SethLavin national pressure on both sides to ...
# 5       246058212946751489  Egypt’s Islamist pres 2take legal action-US ag...
# 6       246058213290688512  RT @keder: How you know Mitt is winning: the m...
# 7       246058214104383489  Obama vows to track down ambassador’s killers,...
# 8       246058214276354050  @T_Whitehead Obama is probably apart of the Mu...
# 9       246058213500407808  RT @JoeBiden: President Obama on the values an...
# 10      246058213903069184  RT @imsure: RT @gerfingerpoken (IBD) Empty-cha...
# 11      246058215027122177  Obama vows to track down ambassador’s killers,...
# 12      246058215832432640  @iowahawkblog Obama has spent more time in Las...
# 13      246058217174622208  Obama vows to track down ambassador’s killers,...
# 14      246058217501761539                          @GoldbergAustin rip Obama
# 15      246058218122534913  Obama vows to track down ambassador’s killers,...
# 16      246058218525192195  Politacs: Embassy Attacked - Obama to Vegas ht...
# 17      246058219162726400  Obama vows to track down ambassador’s killers,...
# 18      246058218986545152  RT @michellemalkin: What a disgusting spectacl...
# 19      246058220404228096      President Obama 4 More Years!!!!!! #Obama2012
# 20      246058220228071424  Obama vows to track down ambassador’s killers,...
# 21      246058219754115072  RT @NiallOfficial: "@AlfredoFlores: http://t.c...
# 22      246058221318578177  Ryan ramps up foreign policy attack on Obama h...
# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
stopWords = set(stopwords.words('english'))
# print(stopWords)

filteredStopWords = {'y', 'he', 'make', 'doing', 'until', 'your', "it's", 'because', 'am', 'here', 'to', 'didn', "you're", 'doesn', 'are', 'had', 'again', 'aren', 'him', 'did', 'couldn', 'where', "won't", 'being', 'before', 'they', 'was', 'both', "needn't", "that'll", 'whom', 'only', 'too', 'out', 'own', "doesn't", 'ma', 'yours', "she's", 'a', 'ourselves', 'me', "shouldn't", 'under', 'then', 'an', 'can', 'o', 'this', "aren't", 'which', 'mustn', 'or', 'each', 'some', 'be', 'down', 'she', 'few', 'won', 'such', 'himself', 'hasn', 'at', 'shan', 'them', 'will', 'between', 'itself', 'our', 'by', 'we', 'up', 'of', 'it', 'don', 'is', 'while', 'than', 'mightn', 'its', "haven't", "isn't", 'theirs', 'd', 'as', 'shouldn', 'over', 'these', 'those', 'there', 'just', 'hers', 'her', 'after', 'for', "wasn't", "you'll", 'his', 'has', 'who', 'having', 'hadn', 'further', 'isn', "you'd", 'ain', 't', 'now', "shan't", 'into', 'been', 'in', 'same', 'any', 'very', 'do', 'if', 'you', "couldn't", 'll', 's', 'below', 'weren', 'their', 'herself', 'he', 'm', 'my', 'and', "mightn't", 'all', 'through', "weren't", 're', 'once', 'why', "didn't", 'needn', 'i', 'yourself', 'what', 'themselves', 'against', "don't", 'myself', 'more', 'ours', 'no', 'yourselves', 'nor', 'with', 'were', "mustn't", "you've", 'that', "wouldn't", 'most', 'wouldn', 'off', 'on', 'should', 've', 'but', 'haven', 'does', 'the', 'from', "should've", 'how', 'during', "hasn't", 'wasn', "hadn't", 'so', 'other', 'about', 'above', 'have', 'when'}

for i in range (0,len(tweets_df)):
    wordsFiltered = []
    words = word_tokenize(tweets_df.iloc[i]['tweet'])
    for w in words:
        if w not in filteredStopWords:
            wordsFiltered.append(w)
    tweets_df.iloc[i]['tweet'] = wordsFiltered

# %%
tweets_df
# Out:
#                         id                                              tweet
# 0       246058206651117568  [Can, please, stop, pretending, Obama, good, m...
# 1       246058207460614144  [RT, @, MotherJones, :, The, official, GOP, re...
# 2       246058208463044608  [RT, @, PolarCoug, :, Obama, would, never, goo...
# 3       246058208584671234  [RT, @, Zack_gale, :, You, cant, bag, Obama, p...
# 4       246058212116267008  [@, SethLavin, national, pressure, sides, end,...
# 5       246058212946751489  [Egypt, ’, Islamist, pres, 2take, legal, actio...
# 6       246058213290688512  [RT, @, keder, :, How, know, Mitt, winning, :,...
# 7       246058214104383489  [Obama, vows, track, ambassador, ’, killers, ,...
# 8       246058214276354050  [@, T_Whitehead, Obama, probably, apart, Musli...
# 9       246058213500407808  [RT, @, JoeBiden, :, President, Obama, values,...
# 10      246058213903069184  [RT, @, imsure, :, RT, @, gerfingerpoken, (, I...
# 11      246058215027122177  [Obama, vows, track, ambassador, ’, killers, ,...
# 12      246058215832432640  [@, iowahawkblog, Obama, spent, time, Las, Veg...
# 13      246058217174622208  [Obama, vows, track, ambassador, ’, killers, ,...
# 14      246058217501761539                    [@, GoldbergAustin, rip, Obama]
# 15      246058218122534913  [Obama, vows, track, ambassador, ’, killers, ,...
# 16      246058218525192195  [Politacs, :, Embassy, Attacked, -, Obama, Veg...
# 354891  246449483796320256  [For, introverted, tweeps, (, I, 've, known, O...
# 354892  246449483867643904  [RT, @, Liz_Cheney, :, Important, piece, Marc,...
# 354893  246449483334955011  [RT, @, AmatoTalk, :, Jimmy, Carter, Corrects,...
# 354894  246449484756819969  [#, OneOfMyFavoriteMusicArtist, obama, http, :...
# 354895  246449486149332992  [@, jmattbarber, could, go, wrong, ?, Obama, O...
# 354896  246449486715580416  [Yall, betta, vote, Obama, abortions, illegal,...
#
# [354897 rows x 2 columns]

# %%
tweets_df.iloc[0]['tweet']
# Out:
# ['Can',
#  'please',
#  'stop',
#  'pretending',
#  'Obama',
#  'good',
#  'man',
#  '?',
#  'He',
#  'not',
#  '.',
#  'Today',
#  'proved',
#  '.',
#  'Being',
#  'good',
#  'father',
#  'alone',
#  'not',
#  'good',
#  'man']

# %%
pos_words = []
neg_words = []

with open('positive.txt') as my_file:
    for line in my_file:
        pos_words.append(line.rstrip())

with open('negative.txt') as my_file:
    for line in my_file:
        neg_words.append(line.rstrip())

# %%
def reviewRating(review, table):
    pos_word_count = 0
    neg_word_count = 0
    words = review

    bo = False
    mr = False
    
    for word in words:
        if word.lower() in ["obama","barack","barackobama","obamabarack"]:
            bo = True
        elif word.lower() in["mitt","romney","mittromney","romneymitt"]:
            mr = True
            
    negate = False
    for word in words:
        w = word.translate(table).lower()
        
        if w is "not":
            # to check if the next word is positive (negative classification) or negative (positive classification)
            negate = True
        elif w in pos_words:
            if (negate):
                neg_word_count = neg_word_count + 1
                negate = False
            else:
                pos_word_count = pos_word_count + 1
        elif w in neg_words:
            if (negate):
                pos_word_count = pos_word_count + 1
                negate = False
            else:
                neg_word_count = neg_word_count + 1
 
    
    if (pos_word_count > neg_word_count and (bo)):
        return "obama positive"
    elif (pos_word_count > neg_word_count and (mr)):
        return "romney positive"
    elif(pos_word_count < neg_word_count and (bo)):
        return "obama negative"
    elif(pos_word_count < neg_word_count and (mr)):
        return "romney negative"
    else:
        return "neutral"

# %%
table = str.maketrans({key: None for key in string.punctuation})
# text = tweets_df.iloc[3]['tweet']

obama_pos = 0
obama_neg = 0
romney_pos = 0
romney_neg = 0
neutral = 0
for i in range (0,len(tweets_df)):
    text = tweets_df.iloc[i]['tweet']
    result = reviewRating(text, table)
    if result == 'obama positive':
        obama_pos = obama_pos + 1
    elif result == 'obama negative':
        obama_neg = obama_neg + 1
    elif result == 'romney positive':
        romney_pos = romney_pos + 1
    elif result == 'romney negative':
        romney_neg = romney_neg + 1
    else:
        neutral = neutral + 1

print('Positive for Obama: ' + str(obama_pos))
print('Negative for Obama: ' + str(obama_neg))
print('Positive for Romney: ' + str(romney_pos))
print('Negative for Romney: ' + str(romney_neg))

total_obama = obama_pos + romney_neg
total_romney = obama_neg + romney_pos

print('Total Votes for Obama: ' + str(total_obama))
print('Total Votes for Romney: ' + str(total_romney))
# Out:
# Positive for Obama: 73195
# Negative for Obama: 109780
# Positive for Romney: 3402
# Negative for Romney: 6071
# Total Votes for Obama: 79266
# Total Votes for Romney: 113182
